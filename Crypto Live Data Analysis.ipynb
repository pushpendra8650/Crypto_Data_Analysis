# %%
import requests

# %%
import pandas as pd

# %%
import time

# %%
from openpyxl import Workbook

# %%
from openpyxl.utils.dataframe import dataframe_to_rows

# %%
def fetch_crypto_data():
    url = "https://api.coingecko.com/api/v3/coins/markets"
    params = {
        "vs_currency": "usd",
        "order": "market_cap_desc",
        "per_page": 50,
        "page": 1,
        "sparkline": False
    }
    response = requests.get(url, params=params)
    data = response.json()
    
    print(data)  # Print before returning
    return data
fetch_crypto_data()
# Out:
# [{'id': 'bitcoin', 'symbol': 'btc', 'name': 'Bitcoin', 'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400', 'current_price': 83784, 'market_cap': 1659945326387, 'market_cap_rank': 1, 'fully_diluted_valuation': 1659945326387, 'total_volume': 74109155624, 'high_24h': 93668, 'low_24h': 82842, 'price_change_24h': -8039.554638590213, 'price_change_percentage_24h': -8.75546, 'market_cap_change_24h': -159339683743.8938, 'market_cap_change_percentage_24h': -8.75837, 'circulating_supply': 19832031.0, 'total_supply': 19832031.0, 'max_supply': 21000000.0, 'ath': 108786, 'ath_change_percentage': -22.87821, 'ath_date': '2025-01-20T09:11:54.494Z', 'atl': 67.81, 'atl_change_percentage': 123625.97228, 'atl_date': '2013-07-06T00:00:00.000Z', 'roi': None, 'last_updated': '2025-03-04T09:31:11.168Z'}, {'id': 'ethereum', 'symbol': 'eth', 'name': 'Ethereum', 'image': 'https://coin-images.coingecko.com/coins/images/279/large/ethereum.png?1696501628', 'current_price': 2090.18, 'market_cap': 251736549098, 'market_cap_rank': 2, 'fully_diluted_valuation': 251736549098, 'total_volume': 36705679454, 'high_24h': 2384.68, 'low_24h': 2035.18, 'price_change_24h': -256.70905570450486, 'price_change_percentage_24h': -10.93826, 'market_cap_change_24h': -30594264541.102295, 'market_cap_change_percentage_24h': -10.83632, 'circulating_supply': 120590104.1967597, 'total_supply': 120590104.1967597, 'max_supply': None, 'ath': 4878.26, 'ath_change_percentage': -57.02488, 'ath_date': '2021-11-10T14:24:19.604Z', 'atl': 0.432979, 'atl_change_percentage': 484089.57007, 'atl_date': '2015-10-20T00:00:00.000Z', 'roi': {'times': 32.35865906166368, 'currency': 'btc', 'percentage': 3235.8659061663675}, 'last_updated': '2025-03-04T09:31:14.656Z'}, {'id': 'tether', 'symbol': 'usdt', 'name': 'Tether', 'image': 'https://coin-images.coingecko.com/coins/images/325/large/Tether.png?1696501661', 'current_price': 0.99948, 'market_cap': 142421775931, 'market_cap_rank': 3, 'fully_diluted_valuation': 142421775931, 'total_volume': 70488305584, 'high_24h': 0.999828, 'low_24h': 0.998981, 'price_change_24h': -0.000173119803714927, 'price_change_percentage_24h': -0.01732, 'market_cap_change_24h': 33798234, 'market_cap_change_percentage_24h': 0.02374, 'circulating_supply': 142508685216.8603, 'total_supply': 142508685216.8603, 'max_supply': None, 'ath': 1.32, 'ath_change_percentage': -24.46637, 'ath_date': '2018-07-24T00:00:00.000Z', 'atl': 0.572521, 'atl_change_percentage': 74.55813, 'atl_date': '2015-03-02T00:00:00.000Z', 'roi': None, 'last_updated': '2025-03-04T09:31:12.214Z'}, {'id': 'ripple', 'symbol': 'xrp', 'name': 'XRP', 'image': 'https://coin-images.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442', 'current_price': 2.35, 'market_cap': 135862241785, 'market_cap_rank': 4, 'fully_diluted_valuation': 234416505266, 'total_volume': 11204675331, 'high_24h': 2.7, 'low_24h': 2.24, 'price_change_24h': -0.23603815347019141, 'price_change_percentage_24h': -9.13576, 'market_cap_change_24h': -13445677145.28418, 'market_cap_change_percentage_24h': -9.00533, 'circulating_supply': 57949738512.0, 'total_supply': 99986390660.0, 'max_supply': 100000000000.0, 'ath': 3.4, 'ath_change_percentage': -30.81168, 'ath_date': '2018-01-07T00:00:00.000Z', 'atl': 0.00268621, 'atl_change_percentage': 87433.48874, 'atl_date': '2014-05-22T00:00:00.000Z', 'roi': None, 'last_updated': '2025-03-04T09:31:10.948Z'}, {'id': 'binancecoin', 'symbol': 'bnb', 'name': 'BNB', 'image': 'https://coin-images.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970', 'current_price': 565.05, 'market_cap': 82404970312, 'market_cap_rank': 5, 'fully_diluted_valuation': 82404970312, 'total_volume': 1135631412, 'high_24h': 608.28, 'low_24h': 548.88, 'price_change_24h': -34.65607165580002, 'price_change_percentage_24h': -5.77885, 'market_cap_change_24h': -5103788622.633133, 'market_cap_change_percentage_24h': -5.83232, 'circulating_supply': 145887575.79, 'total_supply': 145887 ...
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400',
#   'current_price': 83784,
#   'market_cap': 1659945326387,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 1659945326387,
#   'total_volume': 74109155624,
#   'high_24h': 93668,
#   'low_24h': 82842,
#   'price_change_24h': -8039.554638590213,
#   'price_change_percentage_24h': -8.75546,
#   'market_cap_change_24h': -159339683743.8938,
#   'market_cap_change_percentage_24h': -8.75837,
#   'circulating_supply': 19832031.0,
#   'total_supply': 19832031.0,
#   'max_supply': 21000000.0,
#   'ath': 108786,
#   'ath_change_percentage': -22.87821,
#   'ath_date': '2025-01-20T09:11:54.494Z',
#   'atl': 67.81,
#   'atl_change_percentage': 123625.97228,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:11.168Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'image': 'https://coin-images.coingecko.com/coins/images/279/large/ethereum.png?1696501628',
#   'current_price': 2090.18,
#   'market_cap': 251736549098,
#   'market_cap_rank': 2,
#   'fully_diluted_valuation': 251736549098,
#   'total_volume': 36705679454,
#   'high_24h': 2384.68,
#   'low_24h': 2035.18,
#   'price_change_24h': -256.70905570450486,
#   'price_change_percentage_24h': -10.93826,
#   'market_cap_change_24h': -30594264541.102295,
#   'market_cap_change_percentage_24h': -10.83632,
#   'circulating_supply': 120590104.1967597,
#   'total_supply': 120590104.1967597,
#   'max_supply': None,
#   'ath': 4878.26,
#   'ath_change_percentage': -57.02488,
#   'ath_date': '2021-11-10T14:24:19.604Z',
#   'atl': 0.432979,
#   'atl_change_percentage': 484089.57007,
#   'atl_date': '2015-10-20T00:00:00.000Z',
#   'roi': {'times': 32.35865906166368,
#    'currency': 'btc',
#    'percentage': 3235.8659061663675},
#   'last_updated': '2025-03-04T09:31:14.656Z'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://coin-images.coingecko.com/coins/images/325/large/Tether.png?1696501661',
#   'current_price': 0.99948,
#   'market_cap': 142421775931,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 142421775931,
#   'total_volume': 70488305584,
#   'high_24h': 0.999828,
#   'low_24h': 0.998981,
#   'price_change_24h': -0.000173119803714927,
#   'price_change_percentage_24h': -0.01732,
#   'market_cap_change_24h': 33798234,
#   'market_cap_change_percentage_24h': 0.02374,
#   'circulating_supply': 142508685216.8603,
#   'total_supply': 142508685216.8603,
#   'max_supply': None,
#   'ath': 1.32,
#   'ath_change_percentage': -24.46637,
#   'ath_date': '2018-07-24T00:00:00.000Z',
#   'atl': 0.572521,
#   'atl_change_percentage': 74.55813,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:12.214Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://coin-images.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442',
#   'current_price': 2.35,
#   'market_cap': 135862241785,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': 234416505266,
#   'total_volume': 11204675331,
#   'high_24h': 2.7,
#   'low_24h': 2.24,
#   'price_change_24h': -0.23603815347019141,
#   'price_change_percentage_24h': -9.13576,
#   'market_cap_change_24h': -13445677145.28418,
#   'market_cap_change_percentage_24h': -9.00533,
#   'circulating_supply': 57949738512.0,
#   'total_supply': 99986390660.0,
#   'max_supply': 100000000000.0,
#   'ath': 3.4,
#   'ath_change_percentage': -30.81168,
#   'ath_date': '2018-01-07T00:00:00.000Z',
#   'atl': 0.00268621,
#   'atl_change_percentage': 87433.48874,
#   'atl_date': '2014-05-22T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:10.948Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'BNB',
#   'image': 'https://coin-images.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970',
#   'current_price': 565.05,
#   'market_cap': 82404970312,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': 82404970312,
#   'total_volume': 1135631412,
#   'high_24h': 608.28,
#   'low_24h': 548.88,
#   'price_change_24h': -34.65607165580002,
#   'price_change_percentage_24h': -5.77885,
#   'market_cap_change_24h': -5103788622.633133,
#   'market_cap_change_percentage_24h': -5.83232,
#   'circulating_supply': 145887575.79,
#   'total_supply': 145887575.79,
#   'max_supply': 200000000.0,
#   'ath': 788.84,
#   'ath_change_percentage': -28.09303,
#   'ath_date': '2024-12-04T10:35:25.220Z',
#   'atl': 0.0398177,
#   'atl_change_percentage': 1424476.45293,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:11.987Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://coin-images.coingecko.com/coins/images/4128/large/solana.png?1718769756',
#   'current_price': 136.41,
#   'market_cap': 69273901781,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 81213304834,
#   'total_volume': 9909749792,
#   'high_24h': 166.37,
#   'low_24h': 134.33,
#   'price_change_24h': -23.034611375786113,
#   'price_change_percentage_24h': -14.44701,
#   'market_cap_change_24h': -11574416862.741058,
#   'market_cap_change_percentage_24h': -14.31621,
#   'circulating_supply': 507900473.1389096,
#   'total_supply': 595437457.5348855,
#   'max_supply': None,
#   'ath': 293.31,
#   'ath_change_percentage': -53.29369,
#   'ath_date': '2025-01-19T11:15:27.957Z',
#   'atl': 0.500801,
#   'atl_change_percentage': 27255.20386,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:09.988Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USDC',
#   'image': 'https://coin-images.coingecko.com/coins/images/6319/large/usdc.png?1696506694',
#   'current_price': 0.999813,
#   'market_cap': 56262300308,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': 56228141969,
#   'total_volume': 16822964247,
#   'high_24h': 0.999996,
#   'low_24h': 0.999258,
#   'price_change_24h': -7.5062539430015e-05,
#   'price_change_percentage_24h': -0.00751,
#   'market_cap_change_24h': -91144758.56298828,
#   'market_cap_change_percentage_24h': -0.16174,
#   'circulating_supply': 56271636707.67078,
#   'total_supply': 56237472700.46715,
#   'max_supply': None,
#   'ath': 1.17,
#   'ath_change_percentage': -14.75215,
#   'ath_date': '2019-05-08T00:40:28.300Z',
#   'atl': 0.877647,
#   'atl_change_percentage': 13.90767,
#   'atl_date': '2023-03-11T08:02:13.981Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:14.512Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://coin-images.coingecko.com/coins/images/975/large/cardano.png?1696502090',
#   'current_price': 0.807069,
#   'market_cap': 28965681534,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': 36265839946,
#   'total_volume': 5731632961,
#   'high_24h': 1.012,
#   'low_24h': 0.769321,
#   'price_change_24h': -0.14963669493907417,
#   'price_change_percentage_24h': -15.64084,
#   'market_cap_change_24h': -5233910713.222832,
#   'market_cap_change_percentage_24h': -15.30401,
#   'circulating_supply': 35941692539.15861,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 3.09,
#   'ath_change_percentage': -73.84949,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 0.01925275,
#   'atl_change_percentage': 4092.87118,
#   'atl_date': '2020-03-13T02:22:55.044Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:11.528Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/5/large/dogecoin.png?1696501409',
#   'current_price': 0.191972,
#   'market_cap': 28382688767,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': 28426484696,
#   'total_volume': 2682953989,
#   'high_24h': 0.223992,
#   'low_24h': 0.188098,
#   'price_change_24h': -0.02661801592310606,
#   'price_change_percentage_24h': -12.17714,
#   'market_cap_change_24h': -3921457807.7875557,
#   'market_cap_change_percentage_24h': -12.13918,
#   'circulating_supply': 148057346383.7052,
#   'total_supply': 148285806383.7052,
#   'max_supply': None,
#   'ath': 0.731578,
#   'ath_change_percentage': -73.67947,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 8.69e-05,
#   'atl_change_percentage': 221472.93992,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:13.095Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://coin-images.coingecko.com/coins/images/1094/large/tron-logo.png?1696502193',
#   'current_price': 0.233832,
#   'market_cap': 20101650006,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': 20101688009,
#   'total_volume': 1288777912,
#   'high_24h': 0.244926,
#   'low_24h': 0.226671,
#   'price_change_24h': -0.006654748425365981,
#   'price_change_percentage_24h': -2.7672,
#   'market_cap_change_24h': -594288080.2827339,
#   'market_cap_change_percentage_24h': -2.87152,
#   'circulating_supply': 86060604744.21721,
#   'total_supply': 86060767449.13881,
#   'max_supply': None,
#   'ath': 0.431288,
#   'ath_change_percentage': -45.7153,
#   'ath_date': '2024-12-04T00:10:40.323Z',
#   'atl': 0.00180434,
#   'atl_change_percentage': 12875.56984,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 122.06954770797643,
#    'currency': 'usd',
#    'percentage': 12206.954770797642},
#   'last_updated': '2025-03-04T09:31:13.068Z'},
#  {'id': 'staked-ether',
#   'symbol': 'steth',
#   'name': 'Lido Staked Ether',
#   'image': 'https://coin-images.coingecko.com/coins/images/13442/large/steth_logo.png?1696513206',
#   'current_price': 2088.38,
#   'market_cap': 19590164114,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': 19590164114,
#   'total_volume': 152522709,
#   'high_24h': 2376.65,
#   'low_24h': 2027.19,
#   'price_change_24h': -257.2967525386489,
#   'price_change_percentage_24h': -10.969,
#   'market_cap_change_24h': -2440331999.8638687,
#   'market_cap_change_percentage_24h': -11.07706,
#   'circulating_supply': 9396699.683570346,
#   'total_supply': 9396699.683570346,
#   'max_supply': None,
#   'ath': 4829.57,
#   'ath_change_percentage': -56.72359,
#   'ath_date': '2021-11-10T14:40:47.256Z',
#   'atl': 482.9,
#   'atl_change_percentage': 332.81861,
#   'atl_date': '2020-12-22T04:08:21.854Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:19.880Z'},
#  {'id': 'wrapped-bitcoin',
#   'symbol': 'wbtc',
#   'name': 'Wrapped Bitcoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/7598/large/wrapped_bitcoin_wbtc.png?1696507857',
#   'current_price': 83637,
#   'market_cap': 10797865655,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': 10797865655,
#   'total_volume': 816531915,
#   'high_24h': 93440,
#   'low_24h': 82909,
#   'price_change_24h': -7844.998208527308,
#   'price_change_percentage_24h': -8.57547,
#   'market_cap_change_24h': -1018789086.4883842,
#   'market_cap_change_percentage_24h': -8.62164,
#   'circulating_supply': 129138.42002211,
#   'total_supply': 129138.42002211,
#   'max_supply': 129138.42002211,
#   'ath': 108368,
#   'ath_change_percentage': -22.81148,
#   'ath_date': '2025-01-20T07:16:27.137Z',
#   'atl': 3139.17,
#   'atl_change_percentage': 2564.63611,
#   'atl_date': '2019-04-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:14.809Z'},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'image': 'https://coin-images.coingecko.com/coins/images/3688/large/hbar.png?1696504364',
#   'current_price': 0.230575,
#   'market_cap': 9689742353,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': 11560617149,
#   'total_volume': 587068182,
#   'high_24h': 0.255173,
#   'low_24h': 0.221369,
#   'price_change_24h': -0.01753273961075197,
#   'price_change_percentage_24h': -7.06659,
#   'market_cap_change_24h': -693788944.9031658,
#   'market_cap_change_percentage_24h': -6.68163,
#   'circulating_supply': 41908412969.05636,
#   'total_supply': 50000000000.0,
#   'max_supply': 50000000000.0,
#   'ath': 0.569229,
#   'ath_change_percentage': -59.20929,
#   'ath_date': '2021-09-15T10:40:28.318Z',
#   'atl': 0.00986111,
#   'atl_change_percentage': 2254.62874,
#   'atl_date': '2020-01-02T17:30:24.852Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:14.236Z'},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'image': 'https://coin-images.coingecko.com/coins/images/8418/large/leo-token.png?1696508607',
#   'current_price': 9.94,
#   'market_cap': 9195415523,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': 9804721503,
#   'total_volume': 8571424,
#   'high_24h': 10.04,
#   'low_24h': 9.66,
#   'price_change_24h': -0.007284356767881306,
#   'price_change_percentage_24h': -0.07322,
#   'market_cap_change_24h': 2747010,
#   'market_cap_change_percentage_24h': 0.02988,
#   'circulating_supply': 924012642.9,
#   'total_supply': 985239504.0,
#   'max_supply': None,
#   'ath': 10.05,
#   'ath_change_percentage': -3.83479,
#   'ath_date': '2025-03-02T17:40:34.261Z',
#   'atl': 0.799859,
#   'atl_change_percentage': 1108.01492,
#   'atl_date': '2019-12-24T15:14:35.376Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:15.928Z'},
#  {'id': 'wrapped-steth',
#   'symbol': 'wsteth',
#   'name': 'Wrapped stETH',
#   'image': 'https://coin-images.coingecko.com/coins/images/18834/large/wstETH.png?1696518295',
#   'current_price': 2498.73,
#   'market_cap': 8893446083,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': 8893446083,
#   'total_volume': 63656775,
#   'high_24h': 2842.13,
#   'low_24h': 2402.77,
#   'price_change_24h': -298.92194249315753,
#   'price_change_percentage_24h': -10.68473,
#   'market_cap_change_24h': -1036190016.588131,
#   'market_cap_change_percentage_24h': -10.43533,
#   'circulating_supply': 3559334.025385792,
#   'total_supply': 3556596.129697814,
#   'max_supply': None,
#   'ath': 7256.02,
#   'ath_change_percentage': -65.55491,
#   'ath_date': '2022-05-13T15:09:54.509Z',
#   'atl': 558.54,
#   'atl_change_percentage': 347.47784,
#   'atl_date': '2022-05-13T01:36:45.053Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:13.104Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://coin-images.coingecko.com/coins/images/877/large/chainlink-new-logo.png?1696502009',
#   'current_price': 13.73,
#   'market_cap': 8759345866,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': 13727231267,
#   'total_volume': 1002232549,
#   'high_24h': 16.76,
#   'low_24h': 13.52,
#   'price_change_24h': -2.420330430236735,
#   'price_change_percentage_24h': -14.98311,
#   'market_cap_change_24h': -1524590248.6427727,
#   'market_cap_change_percentage_24h': -14.82497,
#   'circulating_supply': 638099970.4505637,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 52.7,
#   'ath_change_percentage': -73.84131,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 0.148183,
#   'atl_change_percentage': 9202.4973,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:12.055Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://coin-images.coingecko.com/coins/images/100/large/fmpFRHHQ_400x400.jpg?1735231350',
#   'current_price': 0.284484,
#   'market_cap': 8717134728,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 14201672989,
#   'total_volume': 382923390,
#   'high_24h': 0.332221,
#   'low_24h': 0.277544,
#   'price_change_24h': -0.042043378791555064,
#   'price_change_percentage_24h': -12.8759,
#   'market_cap_change_24h': -1293577752.6222286,
#   'market_cap_change_percentage_24h': -12.92193,
#   'circulating_supply': 30691617343.38758,
#   'total_supply': 50001786894.45001,
#   'max_supply': 50001786894.45001,
#   'ath': 0.875563,
#   'ath_change_percentage': -67.42194,
#   'ath_date': '2018-01-03T00:00:00.000Z',
#   'atl': 0.00047612,
#   'atl_change_percentage': 59809.14297,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:13.050Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'avax',
#   'name': 'Avalanche',
#   'image': 'https://coin-images.coingecko.com/coins/images/12559/large/Avalanche_Circle_RedWhite_Trans.png?1696512369',
#   'current_price': 19.91,
#   'market_cap': 8242980946,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': 8972893757,
#   'total_volume': 746374531,
#   'high_24h': 23.93,
#   'low_24h': 19.71,
#   'price_change_24h': -3.4403071686206843,
#   'price_change_percentage_24h': -14.73392,
#   'market_cap_change_24h': -1390141161.6329784,
#   'market_cap_change_percentage_24h': -14.43085,
#   'circulating_supply': 414111861.9154439,
#   'total_supply': 450781308.9468947,
#   'max_supply': 720000000.0,
#   'ath': 144.96,
#   'ath_change_percentage': -86.17029,
#   'ath_date': '2021-11-21T14:18:56.538Z',
#   'atl': 2.8,
#   'atl_change_percentage': 615.71785,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:18.741Z'},
#  {'id': 'usds',
#   'symbol': 'usds',
#   'name': 'USDS',
#   'image': 'https://coin-images.coingecko.com/coins/images/39926/large/usds.webp?1726666683',
#   'current_price': 0.999517,
#   'market_cap': 7952214804,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 7952214804,
#   'total_volume': 91872981,
#   'high_24h': 1.003,
#   'low_24h': 0.998035,
#   'price_change_24h': 0.00013314,
#   'price_change_percentage_24h': 0.01332,
#   'market_cap_change_24h': 14551879,
#   'market_cap_change_percentage_24h': 0.18333,
#   'circulating_supply': 7946575922.401469,
#   'total_supply': 7949337642.636502,
#   'max_supply': None,
#   'ath': 1.057,
#   'ath_change_percentage': -5.35933,
#   'ath_date': '2024-10-29T05:40:51.197Z',
#   'atl': 0.948265,
#   'atl_change_percentage': 5.525,
#   'atl_date': '2024-10-03T13:19:28.826Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:12.469Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/2/large/litecoin.png?1696501400',
#   'current_price': 102.46,
#   'market_cap': 7743614525,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 7743631810,
#   'total_volume': 1518709278,
#   'high_24h': 118.66,
#   'low_24h': 100.96,
#   'price_change_24h': -13.968676377226075,
#   'price_change_percentage_24h': -11.99784,
#   'market_cap_change_24h': -1027007940.9326239,
#   'market_cap_change_percentage_24h': -11.70964,
#   'circulating_supply': 75596564.48347135,
#   'total_supply': 75596733.23347135,
#   'max_supply': 84000000.0,
#   'ath': 410.26,
#   'ath_change_percentage': -74.90882,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 1.15,
#   'atl_change_percentage': 8860.24051,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:17.079Z'},
#  {'id': 'sui',
#   'symbol': 'sui',
#   'name': 'Sui',
#   'image': 'https://coin-images.coingecko.com/coins/images/26375/large/sui-ocean-square.png?1727791290',
#   'current_price': 2.41,
#   'market_cap': 7634420862,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': 24084523843,
#   'total_volume': 1331835130,
#   'high_24h': 3.0,
#   'low_24h': 2.41,
#   'price_change_24h': -0.5226778708817501,
#   'price_change_percentage_24h': -17.8304,
#   'market_cap_change_24h': -1652996090.3185558,
#   'market_cap_change_percentage_24h': -17.79823,
#   'circulating_supply': 3169845047.483887,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 5.35,
#   'ath_change_percentage': -54.88511,
#   'ath_date': '2025-01-04T22:56:18.063Z',
#   'atl': 0.364846,
#   'atl_change_percentage': 561.12712,
#   'atl_date': '2023-10-19T10:40:30.078Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:10.942Z'},
#  {'id': 'the-open-network',
#   'symbol': 'ton',
#   'name': 'Toncoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/17980/large/photo_2024-09-10_17.09.00.jpeg?1725963446',
#   'current_price': 3.04,
#   'market_cap': 7537060576,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': 15594788088,
#   'total_volume': 293375216,
#   'high_24h': 3.38,
#   'low_24h': 2.85,
#   'price_change_24h': -0.30744500527082996,
#   'price_change_percentage_24h': -9.17894,
#   'market_cap_change_24h': -805738264.5244665,
#   'market_cap_change_percentage_24h': -9.65789,
#   'circulating_supply': 2476337658.245774,
#   'total_supply': 5123742952.813475,
#   'max_supply': None,
#   'ath': 8.25,
#   'ath_change_percentage': -63.09181,
#   'ath_date': '2024-06-15T00:36:51.509Z',
#   'atl': 0.519364,
#   'atl_change_percentage': 486.53618,
#   'atl_date': '2021-09-21T00:33:11.092Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:11.663Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://coin-images.coingecko.com/coins/images/11939/large/shiba.png?1696511800',
#   'current_price': 1.267e-05,
#   'market_cap': 7463048524,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': 7466258246,
#   'total_volume': 453001061,
#   'high_24h': 1.424e-05,
#   'low_24h': 1.232e-05,
#   'price_change_24h': -1.374067493253e-06,
#   'price_change_percentage_24h': -9.78516,
#   'market_cap_change_24h': -799717882.6313972,
#   'market_cap_change_percentage_24h': -9.67857,
#   'circulating_supply': 589253592357366.4,
#   'total_supply': 589507019662654.4,
#   'max_supply': None,
#   'ath': 8.616e-05,
#   'ath_change_percentage': -85.27501,
#   'ath_date': '2021-10-28T03:54:55.568Z',
#   'atl': 5.6366e-11,
#   'atl_change_percentage': 22507763.49287,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:19.947Z'},
#  {'id': 'mantra-dao',
#   'symbol': 'om',
#   'name': 'MANTRA',
#   'image': 'https://coin-images.coingecko.com/coins/images/12151/large/OM_Token.png?1696511991',
#   'current_price': 6.84,
#   'market_cap': 6668341791,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': 12385179256,
#   'total_volume': 170776664,
#   'high_24h': 7.51,
#   'low_24h': 6.75,
#   'price_change_24h': -0.6757511403706742,
#   'price_change_percentage_24h': -8.99546,
#   'market_cap_change_24h': -662544832.3596363,
#   'market_cap_change_percentage_24h': -9.03772,
#   'circulating_supply': 974714837.4099998,
#   'total_supply': 1810347813.99,
#   'max_supply': None,
#   'ath': 8.99,
#   'ath_change_percentage': -23.58491,
#   'ath_date': '2025-02-23T01:52:21.073Z',
#   'atl': 0.01726188,
#   'atl_change_percentage': 39676.5244,
#   'atl_date': '2023-10-12T17:25:09.068Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:15.465Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://coin-images.coingecko.com/coins/images/12171/large/polkadot.png?1696512008',
#   'current_price': 4.24,
#   'market_cap': 6473417238,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': 6473417238,
#   'total_volume': 370360401,
#   'high_24h': 5.01,
#   'low_24h': 4.18,
#   'price_change_24h': -0.619559463061047,
#   'price_change_percentage_24h': -12.74066,
#   'market_cap_change_24h': -917762586.6650562,
#   'market_cap_change_percentage_24h': -12.417,
#   'circulating_supply': 1522267060.0,
#   'total_supply': 1522267060.0,
#   'max_supply': None,
#   'ath': 54.98,
#   'ath_change_percentage': -92.24013,
#   'ath_date': '2021-11-04T14:10:09.301Z',
#   'atl': 2.7,
#   'atl_change_percentage': 58.16557,
#   'atl_date': '2020-08-20T05:48:11.359Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:18.009Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://coin-images.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1696501932',
#   'current_price': 309.72,
#   'market_cap': 6146412240,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': 6146444192,
#   'total_volume': 596568693,
#   'high_24h': 347.11,
#   'low_24h': 301.9,
#   'price_change_24h': -6.041996901669108,
#   'price_change_percentage_24h': -1.91349,
#   'market_cap_change_24h': -95599047.70009613,
#   'market_cap_change_percentage_24h': -1.53154,
#   'circulating_supply': 19837203.02165078,
#   'total_supply': 19837306.14665078,
#   'max_supply': 21000000.0,
#   'ath': 3785.82,
#   'ath_change_percentage': -91.7586,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 76.93,
#   'atl_change_percentage': 305.54395,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:19.924Z'},
#  {'id': 'weth',
#   'symbol': 'weth',
#   'name': 'WETH',
#   'image': 'https://coin-images.coingecko.com/coins/images/2518/large/weth.png?1696503332',
#   'current_price': 2088.96,
#   'market_cap': 5990335932,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': 5990335932,
#   'total_volume': 1624000579,
#   'high_24h': 2386.24,
#   'low_24h': 2023.25,
#   'price_change_24h': -257.6429140598748,
#   'price_change_percentage_24h': -10.97941,
#   'market_cap_change_24h': -738753226.3473549,
#   'market_cap_change_percentage_24h': -10.9785,
#   'circulating_supply': 2867744.988071799,
#   'total_supply': 2867744.988071799,
#   'max_supply': None,
#   'ath': 4799.89,
#   'ath_change_percentage': -56.35357,
#   'ath_date': '2021-11-09T00:00:00.000Z',
#   'atl': 82.1,
#   'atl_change_percentage': 2451.63796,
#   'atl_date': '2018-12-15T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:15.169Z'},
#  {'id': 'ethena-usde',
#   'symbol': 'usde',
#   'name': 'Ethena USDe',
#   'image': 'https://coin-images.coingecko.com/coins/images/33613/large/usde.png?1733810059',
#   'current_price': 0.99834,
#   'market_cap': 5450223589,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': 5450223589,
#   'total_volume': 105311466,
#   'high_24h': 1.0,
#   'low_24h': 0.997537,
#   'price_change_24h': -0.001692900676593112,
#   'price_change_percentage_24h': -0.16928,
#   'market_cap_change_24h': -13509950.932344437,
#   'market_cap_change_percentage_24h': -0.24727,
#   'circulating_supply': 5459454454.956164,
#   'total_supply': 5458581927.908165,
#   'max_supply': None,
#   'ath': 1.032,
#   'ath_change_percentage': -3.26229,
#   'ath_date': '2023-12-20T15:38:34.596Z',
#   'atl': 0.929486,
#   'atl_change_percentage': 7.41556,
#   'atl_date': '2024-10-04T07:57:15.809Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:12.410Z'},
#  {'id': 'hyperliquid',
#   'symbol': 'hype',
#   'name': 'Hyperliquid',
#   'image': 'https://coin-images.coingecko.com/coins/images/50882/large/hyperliquid.jpg?1729431300',
#   'current_price': 15.83,
#   'market_cap': 5323706148,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': 15942514922,
#   'total_volume': 328016106,
#   'high_24h': 19.91,
#   'low_24h': 15.83,
#   'price_change_24h': -3.5261447554046264,
#   'price_change_percentage_24h': -18.22064,
#   'market_cap_change_24h': -1129810843.686264,
#   'market_cap_change_percentage_24h': -17.5069,
#   'circulating_supply': 333928180.0,
#   'total_supply': 999990391.0,
#   'max_supply': 1000000000.0,
#   'ath': 34.96,
#   'ath_change_percentage': -54.39647,
#   'ath_date': '2024-12-22T03:56:00.276Z',
#   'atl': 3.81,
#   'atl_change_percentage': 318.58156,
#   'atl_date': '2024-11-29T09:30:30.871Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:14.262Z'},
#  {'id': 'bitget-token',
#   'symbol': 'bgb',
#   'name': 'Bitget Token',
#   'image': 'https://coin-images.coingecko.com/coins/images/11610/large/Bitget_logo.png?1736925727',
#   'current_price': 4.17,
#   'market_cap': 4998935730,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': 4998935730,
#   'total_volume': 352856176,
#   'high_24h': 4.65,
#   'low_24h': 4.1,
#   'price_change_24h': -0.47932789167595047,
#   'price_change_percentage_24h': -10.31851,
#   'market_cap_change_24h': -575447633.0670929,
#   'market_cap_change_percentage_24h': -10.32307,
#   'circulating_supply': 1199999994.2,
#   'total_supply': 1199999994.2,
#   'max_supply': 2000000000.0,
#   'ath': 8.45,
#   'ath_change_percentage': -50.73639,
#   'ath_date': '2024-12-27T11:41:24.992Z',
#   'atl': 0.0142795,
#   'atl_change_percentage': 29053.22082,
#   'atl_date': '2020-06-25T04:17:05.895Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:08.840Z'},
#  {'id': 'whitebit',
#   'symbol': 'wbt',
#   'name': 'WhiteBIT Coin',
#   'image': 'https://coin-images.coingecko.com/coins/images/27045/large/wbt_token.png?1696526096',
#   'current_price': 29.64,
#   'market_cap': 4271512931,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': 9788614155,
#   'total_volume': 143788922,
#   'high_24h': 30.89,
#   'low_24h': 29.3,
#   'price_change_24h': -0.9722559852865409,
#   'price_change_percentage_24h': -3.17615,
#   'market_cap_change_24h': -141661599.2454319,
#   'market_cap_change_percentage_24h': -3.20997,
#   'circulating_supply': 144118517.10815412,
#   'total_supply': 330262504.0,
#   'max_supply': 400000000.0,
#   'ath': 31.28,
#   'ath_change_percentage': -5.47837,
#   'ath_date': '2025-03-02T22:22:36.852Z',
#   'atl': 3.06,
#   'atl_change_percentage': 865.54595,
#   'atl_date': '2023-02-13T19:01:21.899Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:13.450Z'},
#  {'id': 'wrapped-eeth',
#   'symbol': 'weeth',
#   'name': 'Wrapped eETH',
#   'image': 'https://coin-images.coingecko.com/coins/images/33033/large/weETH.png?1701438396',
#   'current_price': 2216.15,
#   'market_cap': 4253529148,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': 4253529148,
#   'total_volume': 29342801,
#   'high_24h': 2530.86,
#   'low_24h': 2157.49,
#   'price_change_24h': -270.73601391387183,
#   'price_change_percentage_24h': -10.88656,
#   'market_cap_change_24h': -539193167.8514352,
#   'market_cap_change_percentage_24h': -11.25025,
#   'circulating_supply': 1922613.14113841,
#   'total_supply': 1922613.14113841,
#   'max_supply': None,
#   'ath': 4311.81,
#   'ath_change_percentage': -48.58406,
#   'ath_date': '2024-12-06T20:32:25.758Z',
#   'atl': 2157.49,
#   'atl_change_percentage': 2.75614,
#   'atl_date': '2025-03-04T02:21:06.792Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:13.041Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://coin-images.coingecko.com/coins/images/12504/large/uniswap-logo.png?1720676669',
#   'current_price': 6.77,
#   'market_cap': 4063212426,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': 6766572787,
#   'total_volume': 321287157,
#   'high_24h': 8.0,
#   'low_24h': 6.67,
#   'price_change_24h': -1.075377651962114,
#   'price_change_percentage_24h': -13.70274,
#   'market_cap_change_24h': -647043582.706995,
#   'market_cap_change_percentage_24h': -13.73691,
#   'circulating_supply': 600483073.71,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 44.92,
#   'ath_change_percentage': -84.88661,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 1.03,
#   'atl_change_percentage': 558.98218,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:13.263Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://coin-images.coingecko.com/coins/images/69/large/monero_logo.png?1696501460',
#   'current_price': 212.91,
#   'market_cap': 3927592340,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': 3927592340,
#   'total_volume': 62917479,
#   'high_24h': 234.21,
#   'low_24h': 211.47,
#   'price_change_24h': -21.12613364022215,
#   'price_change_percentage_24h': -9.02694,
#   'market_cap_change_24h': -386783250.9255376,
#   'market_cap_change_percentage_24h': -8.96499,
#   'circulating_supply': 18446744.07370955,
#   'total_supply': 18446744.07370955,
#   'max_supply': None,
#   'ath': 542.33,
#   'ath_change_percentage': -60.64515,
#   'ath_date': '2018-01-09T00:00:00.000Z',
#   'atl': 0.216177,
#   'atl_change_percentage': 98630.08115,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:15.426Z'},
#  {'id': 'near',
#   'symbol': 'near',
#   'name': 'NEAR Protocol',
#   'image': 'https://coin-images.coingecko.com/coins/images/10365/large/near.jpg?1696510367',
#   'current_price': 2.79,
#   'market_cap': 3317437688,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': 3456377573,
#   'total_volume': 387348194,
#   'high_24h': 3.34,
#   'low_24h': 2.79,
#   'price_change_24h': -0.4804025674681567,
#   'price_change_percentage_24h': -14.6778,
#   'market_cap_change_24h': -563486598.843503,
#   'market_cap_change_percentage_24h': -14.51939,
#   'circulating_supply': 1188469622.0,
#   'total_supply': 1238244734.0,
#   'max_supply': None,
#   'ath': 20.44,
#   'ath_change_percentage': -86.28538,
#   'ath_date': '2022-01-16T22:09:45.873Z',
#   'atl': 0.526762,
#   'atl_change_percentage': 432.12048,
#   'atl_date': '2020-11-04T16:09:15.137Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:16.674Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://coin-images.coingecko.com/coins/images/9956/large/Badge_Dai.png?1696509996',
#   'current_price': 0.99981,
#   'market_cap': 3286110773,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': 3286110773,
#   'total_volume': 233806901,
#   'high_24h': 1.0,
#   'low_24h': 0.998988,
#   'price_change_24h': 0.00051628,
#   'price_change_percentage_24h': 0.05166,
#   'market_cap_change_24h': -16217774.179186821,
#   'market_cap_change_percentage_24h': -0.4911,
#   'circulating_supply': 3286904064.872771,
#   'total_supply': 3286904064.872771,
#   'max_supply': None,
#   'ath': 1.22,
#   'ath_change_percentage': -17.99191,
#   'ath_date': '2020-03-13T03:02:50.373Z',
#   'atl': 0.88196,
#   'atl_change_percentage': 13.34094,
#   'atl_date': '2023-03-11T07:50:50.514Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:12.141Z'},
#  {'id': 'aptos',
#   'symbol': 'apt',
#   'name': 'Aptos',
#   'image': 'https://coin-images.coingecko.com/coins/images/26455/large/aptos_round.png?1696525528',
#   'current_price': 5.4,
#   'market_cap': 3185116815,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': 6175368181,
#   'total_volume': 360560274,
#   'high_24h': 6.43,
#   'low_24h': 5.37,
#   'price_change_24h': -0.9403649806065175,
#   'price_change_percentage_24h': -14.82292,
#   'market_cap_change_24h': -557556983.3992786,
#   'market_cap_change_percentage_24h': -14.89729,
#   'circulating_supply': 589388412.7413868,
#   'total_supply': 1142718042.08532,
#   'max_supply': None,
#   'ath': 19.92,
#   'ath_change_percentage': -72.84048,
#   'ath_date': '2023-01-26T14:25:17.390Z',
#   'atl': 3.08,
#   'atl_change_percentage': 75.67028,
#   'atl_date': '2022-12-29T21:35:14.796Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:18.129Z'},
#  {'id': 'susds',
#   'symbol': 'susds',
#   'name': 'sUSDS',
#   'image': 'https://coin-images.coingecko.com/coins/images/52721/large/sUSDS_Coin.png?1734086971',
#   'current_price': 1.042,
#   'market_cap': 3009445147,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': 3009445147,
#   'total_volume': 1837046,
#   'high_24h': 1.045,
#   'low_24h': 1.03,
#   'price_change_24h': -6.2700544373406e-05,
#   'price_change_percentage_24h': -0.00602,
#   'market_cap_change_24h': 37639728,
#   'market_cap_change_percentage_24h': 1.26656,
#   'circulating_supply': 2890444932.537777,
#   'total_supply': 2890444932.537777,
#   'max_supply': None,
#   'ath': 1.088,
#   'ath_change_percentage': -3.9763,
#   'ath_date': '2025-02-03T02:31:35.208Z',
#   'atl': 0.961716,
#   'atl_change_percentage': 8.62412,
#   'atl_date': '2025-01-04T01:21:08.460Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:20.397Z'},
#  {'id': 'ondo-finance',
#   'symbol': 'ondo',
#   'name': 'Ondo',
#   'image': 'https://coin-images.coingecko.com/coins/images/26580/large/ONDO.png?1696525656',
#   'current_price': 0.919723,
#   'market_cap': 2905271799,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': 9196495442,
#   'total_volume': 363981662,
#   'high_24h': 1.17,
#   'low_24h': 0.916488,
#   'price_change_24h': -0.18848165302747388,
#   'price_change_percentage_24h': -17.00783,
#   'market_cap_change_24h': -596071157.9472027,
#   'market_cap_change_percentage_24h': -17.02407,
#   'circulating_supply': 3159107529.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.14,
#   'ath_change_percentage': -57.07246,
#   'ath_date': '2024-12-16T00:36:00.777Z',
#   'atl': 0.082171,
#   'atl_change_percentage': 1018.05463,
#   'atl_date': '2024-01-18T12:14:30.524Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:16.945Z'},
#  {'id': 'pepe',
#   'symbol': 'pepe',
#   'name': 'Pepe',
#   'image': 'https://coin-images.coingecko.com/coins/images/29850/large/pepe-token.jpeg?1696528776',
#   'current_price': 6.9e-06,
#   'market_cap': 2899863839,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': 2899863839,
#   'total_volume': 1052470232,
#   'high_24h': 8.44e-06,
#   'low_24h': 6.64e-06,
#   'price_change_24h': -1.335198627643e-06,
#   'price_change_percentage_24h': -16.21712,
#   'market_cap_change_24h': -562266777.7747855,
#   'market_cap_change_percentage_24h': -16.24048,
#   'circulating_supply': 420690000000000.0,
#   'total_supply': 420690000000000.0,
#   'max_supply': 420690000000000.0,
#   'ath': 2.803e-05,
#   'ath_change_percentage': -75.37094,
#   'ath_date': '2024-12-09T16:30:35.828Z',
#   'atl': 5.5142e-08,
#   'atl_change_percentage': 12418.64051,
#   'atl_date': '2023-04-18T02:14:41.591Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:17.747Z'},
#  {'id': 'internet-computer',
#   'symbol': 'icp',
#   'name': 'Internet Computer',
#   'image': 'https://coin-images.coingecko.com/coins/images/14495/large/Internet_Computer_logo.png?1696514180',
#   'current_price': 5.91,
#   'market_cap': 2841215220,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': 3129695097,
#   'total_volume': 136324000,
#   'high_24h': 6.86,
#   'low_24h': 5.86,
#   'price_change_24h': -0.8604063484075999,
#   'price_change_percentage_24h': -12.70633,
#   'market_cap_change_24h': -404457280.38375235,
#   'market_cap_change_percentage_24h': -12.46143,
#   'circulating_supply': 481375133.8249167,
#   'total_supply': 530251064.840837,
#   'max_supply': None,
#   'ath': 700.65,
#   'ath_change_percentage': -99.15402,
#   'ath_date': '2021-05-10T16:05:53.653Z',
#   'atl': 2.87,
#   'atl_change_percentage': 106.8865,
#   'atl_date': '2023-09-22T00:29:57.369Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:14.999Z'},
#  {'id': 'ethereum-classic',
#   'symbol': 'etc',
#   'name': 'Ethereum Classic',
#   'image': 'https://coin-images.coingecko.com/coins/images/453/large/ethereum-classic-logo.png?1696501717',
#   'current_price': 18.33,
#   'market_cap': 2764807565,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': 2764807565,
#   'total_volume': 171526806,
#   'high_24h': 20.22,
#   'low_24h': 17.87,
#   'price_change_24h': -1.5150079963827707,
#   'price_change_percentage_24h': -7.63569,
#   'market_cap_change_24h': -223402797.23229837,
#   'market_cap_change_percentage_24h': -7.47614,
#   'circulating_supply': 150980414.9985573,
#   'total_supply': 150980414.9985573,
#   'max_supply': 210700000.0,
#   'ath': 167.09,
#   'ath_change_percentage': -89.00012,
#   'ath_date': '2021-05-06T18:34:22.133Z',
#   'atl': 0.615038,
#   'atl_change_percentage': 2888.30164,
#   'atl_date': '2016-07-25T00:00:00.000Z',
#   'roi': {'times': 39.724742363476174,
#    'currency': 'usd',
#    'percentage': 3972.474236347618},
#   'last_updated': '2025-03-04T09:31:13.211Z'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'image': 'https://coin-images.coingecko.com/coins/images/12645/large/aave-token-round.png?1720472354',
#   'current_price': 173.97,
#   'market_cap': 2619711872,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': 2778851950,
#   'total_volume': 409512874,
#   'high_24h': 212.06,
#   'low_24h': 168.97,
#   'price_change_24h': -31.301164525290915,
#   'price_change_percentage_24h': -15.24897,
#   'market_cap_change_24h': -470964680.24942446,
#   'market_cap_change_percentage_24h': -15.23824,
#   'circulating_supply': 15083707.480990946,
#   'total_supply': 16000000.0,
#   'max_supply': 16000000.0,
#   'ath': 661.69,
#   'ath_change_percentage': -73.69662,
#   'ath_date': '2021-05-18T21:19:59.514Z',
#   'atl': 26.02,
#   'atl_change_percentage': 568.81553,
#   'atl_date': '2020-11-05T09:20:11.928Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:18.550Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://coin-images.coingecko.com/coins/images/4463/large/WeChat_Image_20220118095654.png?1696505053',
#   'current_price': 42.27,
#   'market_cap': 2534019686,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': 9965356995,
#   'total_volume': 30599963,
#   'high_24h': 46.7,
#   'low_24h': 42.03,
#   'price_change_24h': -3.969027448451534,
#   'price_change_percentage_24h': -8.58368,
#   'market_cap_change_24h': -244669426.21144152,
#   'market_cap_change_percentage_24h': -8.80521,
#   'circulating_supply': 60000000.0,
#   'total_supply': 235957685.3,
#   'max_supply': 300000000.0,
#   'ath': 73.8,
#   'ath_change_percentage': -42.67207,
#   'ath_date': '2024-03-14T00:30:12.502Z',
#   'atl': 0.580608,
#   'atl_change_percentage': 7187.17633,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:16.347Z'},
#  {'id': 'gatechain-token',
#   'symbol': 'gt',
#   'name': 'Gate',
#   'image': 'https://coin-images.coingecko.com/coins/images/8183/large/200X200.png?1735246724',
#   'current_price': 20.0,
#   'market_cap': 2516408335,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': 6000235753,
#   'total_volume': 23504813,
#   'high_24h': 22.16,
#   'low_24h': 19.85,
#   'price_change_24h': -1.8686289783233399,
#   'price_change_percentage_24h': -8.54411,
#   'market_cap_change_24h': -235899601.92498493,
#   'market_cap_change_percentage_24h': -8.57097,
#   'circulating_supply': 125815473.19980882,
#   'total_supply': 300000000.0,
#   'max_supply': None,
#   'ath': 25.94,
#   'ath_change_percentage': -22.88047,
#   'ath_date': '2025-01-25T03:07:37.823Z',
#   'atl': 0.25754,
#   'atl_change_percentage': 7667.47083,
#   'atl_date': '2020-03-13T02:18:02.481Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:13.419Z'},
#  {'id': 'official-trump',
#   'symbol': 'trump',
#   'name': 'Official Trump',
#   'image': 'https://coin-images.coingecko.com/coins/images/53746/large/trump.png?1737171561',
#   'current_price': 12.24,
#   'market_cap': 2448440003,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': 12242201401,
#   'total_volume': 2200537086,
#   'high_24h': 15.64,
#   'low_24h': 11.91,
#   'price_change_24h': -2.822180809089268,
#   'price_change_percentage_24h': -18.73334,
#   'market_cap_change_24h': -544901196.9125662,
#   'market_cap_change_percentage_24h': -18.20378,
#   'circulating_supply': 199999977.336,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 73.43,
#   'ath_change_percentage': -83.3512,
#   'ath_date': '2025-01-19T11:50:34.806Z',
#   'atl': 4.29,
#   'atl_change_percentage': 184.92765,
#   'atl_date': '2025-01-18T03:40:29.231Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:17.152Z'},
#  {'id': 'mantle',
#   'symbol': 'mnt',
#   'name': 'Mantle',
#   'image': 'https://coin-images.coingecko.com/coins/images/30980/large/Mantle-Logo-mark.png?1739213200',
#   'current_price': 0.720479,
#   'market_cap': 2422897622,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': 4478495268,
#   'total_volume': 118221506,
#   'high_24h': 0.768459,
#   'low_24h': 0.710267,
#   'price_change_24h': -0.03889353806672324,
#   'price_change_percentage_24h': -5.1218,
#   'market_cap_change_24h': -127706922.2808094,
#   'market_cap_change_percentage_24h': -5.00693,
#   'circulating_supply': 3364694382.83684,
#   'total_supply': 6219316794.99,
#   'max_supply': 6219316794.99,
#   'ath': 1.54,
#   'ath_change_percentage': -53.23441,
#   'ath_date': '2024-04-08T09:45:25.482Z',
#   'atl': 0.307978,
#   'atl_change_percentage': 133.64963,
#   'atl_date': '2023-10-18T02:50:46.942Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:15.491Z'},
#  {'id': 'coinbase-wrapped-btc',
#   'symbol': 'cbbtc',
#   'name': 'Coinbase Wrapped BTC',
#   'image': 'https://coin-images.coingecko.com/coins/images/40143/large/cbbtc.webp?1726136727',
#   'current_price': 83735,
#   'market_cap': 2404423478,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': 2404423478,
#   'total_volume': 514416953,
#   'high_24h': 93647,
#   'low_24h': 82968,
#   'price_change_24h': -8052.339470106323,
#   'price_change_percentage_24h': -8.77281,
#   'market_cap_change_24h': -211110420.56552172,
#   'market_cap_change_percentage_24h': -8.07141,
#   'circulating_supply': 28723.68343061,
#   'total_supply': 28723.68343061,
#   'max_supply': None,
#   'ath': 108953,
#   'ath_change_percentage': -23.17367,
#   'ath_date': '2025-01-20T09:20:53.854Z',
#   'atl': 57439,
#   'atl_change_percentage': 45.72818,
#   'atl_date': '2024-09-12T14:07:41.775Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:12.216Z'},
#  {'id': 'tokenize-xchange',
#   'symbol': 'tkx',
#   'name': 'Tokenize Xchange',
#   'image': 'https://coin-images.coingecko.com/coins/images/4984/large/TKX_-_Logo_-_RGB-15.png?1696505519',
#   'current_price': 29.05,
#   'market_cap': 2321827843,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': 2902429960,
#   'total_volume': 14725315,
#   'high_24h': 29.73,
#   'low_24h': 28.71,
#   'price_change_24h': -0.3560196061663241,
#   'price_change_percentage_24h': -1.21082,
#   'market_cap_change_24h': -34898604.04950762,
#   'market_cap_change_percentage_24h': -1.48081,
#   'circulating_supply': 79995999.05112354,
#   'total_supply': 100000000.0,
#   'max_supply': 100000000.0,
#   'ath': 50.43,
#   'ath_change_percentage': -42.1997,
#   'ath_date': '2025-01-03T19:12:43.038Z',
#   'atl': 0.111255,
#   'atl_change_percentage': 26100.66268,
#   'atl_date': '2019-04-28T00:00:00.000Z',
#   'roi': {'times': 98.99011799043741,
#    'currency': 'usd',
#    'percentage': 9899.011799043741},
#   'last_updated': '2025-03-04T09:31:11.688Z'},
#  {'id': 'bittensor',
#   'symbol': 'tao',
#   'name': 'Bittensor',
#   'image': 'https://coin-images.coingecko.com/coins/images/28452/large/ARUsPeNQ_400x400.jpeg?1696527447',
#   'current_price': 273.86,
#   'market_cap': 2309587788,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 5750923329,
#   'total_volume': 118480692,
#   'high_24h': 333.88,
#   'low_24h': 273.77,
#   'price_change_24h': -49.36271822579158,
#   'price_change_percentage_24h': -15.27207,
#   'market_cap_change_24h': -423763249.77725315,
#   'market_cap_change_percentage_24h': -15.50343,
#   'circulating_supply': 8433662.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 757.6,
#   'ath_change_percentage': -63.76133,
#   'ath_date': '2024-03-07T18:45:36.466Z',
#   'atl': 30.83,
#   'atl_change_percentage': 790.51635,
#   'atl_date': '2023-05-14T08:57:53.732Z',
#   'roi': None,
#   'last_updated': '2025-03-04T09:31:19.336Z'}]

# %%
def analyze_data(data):
    df = pd.DataFrame(data)[["name", "symbol", "current_price", "market_cap", "total_volume", "price_change_percentage_24h"]]
    df.columns = ["Cryptocurrency Name", "Symbol", "Current Price (USD)", "Market Capitalization", "24h Trading Volume", "24h Price Change (%)"]
    
    top_5_by_market_cap = df.nlargest(5, "Market Capitalization")
    avg_price = df["Current Price (USD)"].mean()
    highest_24h_change = df.nlargest(1, "24h Price Change (%)")
    lowest_24h_change = df.nsmallest(1, "24h Price Change (%)")
    print(df, top_5_by_market_cap, avg_price, highest_24h_change, lowest_24h_change)
    return df, top_5_by_market_cap, avg_price, highest_24h_change, lowest_24h_change
    
data = fetch_crypto_data()  # Fetch live crypto data
df, top_5, avg_price, high_change, low_change = analyze_data(data)
# Out:
# [{'id': 'bitcoin', 'symbol': 'btc', 'name': 'Bitcoin', 'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400', 'current_price': 83784, 'market_cap': 1659945326387, 'market_cap_rank': 1, 'fully_diluted_valuation': 1659945326387, 'total_volume': 74109155624, 'high_24h': 93668, 'low_24h': 82842, 'price_change_24h': -8039.554638590213, 'price_change_percentage_24h': -8.75546, 'market_cap_change_24h': -159339683743.8938, 'market_cap_change_percentage_24h': -8.75837, 'circulating_supply': 19832031.0, 'total_supply': 19832031.0, 'max_supply': 21000000.0, 'ath': 108786, 'ath_change_percentage': -22.87821, 'ath_date': '2025-01-20T09:11:54.494Z', 'atl': 67.81, 'atl_change_percentage': 123625.97228, 'atl_date': '2013-07-06T00:00:00.000Z', 'roi': None, 'last_updated': '2025-03-04T09:31:11.168Z'}, {'id': 'ethereum', 'symbol': 'eth', 'name': 'Ethereum', 'image': 'https://coin-images.coingecko.com/coins/images/279/large/ethereum.png?1696501628', 'current_price': 2090.18, 'market_cap': 251736549098, 'market_cap_rank': 2, 'fully_diluted_valuation': 251736549098, 'total_volume': 36705679454, 'high_24h': 2384.68, 'low_24h': 2035.18, 'price_change_24h': -256.70905570450486, 'price_change_percentage_24h': -10.93826, 'market_cap_change_24h': -30594264541.102295, 'market_cap_change_percentage_24h': -10.83632, 'circulating_supply': 120590104.1967597, 'total_supply': 120590104.1967597, 'max_supply': None, 'ath': 4878.26, 'ath_change_percentage': -57.02488, 'ath_date': '2021-11-10T14:24:19.604Z', 'atl': 0.432979, 'atl_change_percentage': 484089.57007, 'atl_date': '2015-10-20T00:00:00.000Z', 'roi': {'times': 32.35865906166368, 'currency': 'btc', 'percentage': 3235.8659061663675}, 'last_updated': '2025-03-04T09:31:14.656Z'}, {'id': 'tether', 'symbol': 'usdt', 'name': 'Tether', 'image': 'https://coin-images.coingecko.com/coins/images/325/large/Tether.png?1696501661', 'current_price': 0.99948, 'market_cap': 142421775931, 'market_cap_rank': 3, 'fully_diluted_valuation': 142421775931, 'total_volume': 70488305584, 'high_24h': 0.999828, 'low_24h': 0.998981, 'price_change_24h': -0.000173119803714927, 'price_change_percentage_24h': -0.01732, 'market_cap_change_24h': 33798234, 'market_cap_change_percentage_24h': 0.02374, 'circulating_supply': 142508685216.8603, 'total_supply': 142508685216.8603, 'max_supply': None, 'ath': 1.32, 'ath_change_percentage': -24.46637, 'ath_date': '2018-07-24T00:00:00.000Z', 'atl': 0.572521, 'atl_change_percentage': 74.55813, 'atl_date': '2015-03-02T00:00:00.000Z', 'roi': None, 'last_updated': '2025-03-04T09:31:12.214Z'}, {'id': 'ripple', 'symbol': 'xrp', 'name': 'XRP', 'image': 'https://coin-images.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442', 'current_price': 2.35, 'market_cap': 135862241785, 'market_cap_rank': 4, 'fully_diluted_valuation': 234416505266, 'total_volume': 11204675331, 'high_24h': 2.7, 'low_24h': 2.24, 'price_change_24h': -0.23603815347019141, 'price_change_percentage_24h': -9.13576, 'market_cap_change_24h': -13445677145.28418, 'market_cap_change_percentage_24h': -9.00533, 'circulating_supply': 57949738512.0, 'total_supply': 99986390660.0, 'max_supply': 100000000000.0, 'ath': 3.4, 'ath_change_percentage': -30.81168, 'ath_date': '2018-01-07T00:00:00.000Z', 'atl': 0.00268621, 'atl_change_percentage': 87433.48874, 'atl_date': '2014-05-22T00:00:00.000Z', 'roi': None, 'last_updated': '2025-03-04T09:31:10.948Z'}, {'id': 'binancecoin', 'symbol': 'bnb', 'name': 'BNB', 'image': 'https://coin-images.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970', 'current_price': 565.05, 'market_cap': 82404970312, 'market_cap_rank': 5, 'fully_diluted_valuation': 82404970312, 'total_volume': 1135631412, 'high_24h': 608.28, 'low_24h': 548.88, 'price_change_24h': -34.65607165580002, 'price_change_percentage_24h': -5.77885, 'market_cap_change_24h': -5103788622.633133, 'market_cap_change_percentage_24h': -5.83232, 'circulating_supply': 145887575.79, 'total_supply': 145887 ...
#      Cryptocurrency Name  Symbol  Current Price (USD)  Market Capitalization  \
# 0                Bitcoin     btc         83784.000000          1659945326387
# 1               Ethereum     eth          2090.180000           251736549098
# 2                 Tether    usdt             0.999480           142421775931
# 3                    XRP     xrp             2.350000           135862241785
# 4                    BNB     bnb           565.050000            82404970312
# 5                 Solana     sol           136.410000            69273901781
# 6                   USDC    usdc             0.999813            56262300308
# 7                Cardano     ada             0.807069            28965681534
# 8               Dogecoin    doge             0.191972            28382688767
# 9                   TRON     trx             0.233832            20101650006
# 10     Lido Staked Ether   steth          2088.380000            19590164114
# 11       Wrapped Bitcoin    wbtc         83637.000000            10797865655
# 12                Hedera    hbar             0.230575             9689742353
# 13             LEO Token     leo             9.940000             9195415523
# 14         Wrapped stETH  wsteth          2498.730000             8893446083
# 15             Chainlink    link            13.730000             8759345866
# 16               Stellar     xlm             0.284484             8717134728
# 17             Avalanche    avax            19.910000             8242980946
# 18                  USDS    usds             0.999517             7952214804
# 19              Litecoin     ltc           102.460000             7743614525
# 20                   Sui     sui             2.410000             7634420862
# 21               Toncoin     ton             3.040000             7537060576
# 22             Shiba Inu    shib             0.000013             7463048524
# 23                MANTRA      om             6.840000             6668341791
# 24              Polkadot     dot             4.240000             6473417238
# 25          Bitcoin Cash     bch           309.720000             6146412240
# 26                  WETH    weth          2088.960000             5990335932
# 27           Ethena USDe    usde             0.998340             5450223589
# 28           Hyperliquid    hype            15.830000             5323706148
# 29          Bitget Token     bgb             4.170000             4998935730
# 30         WhiteBIT Coin     wbt            29.640000             4271512931
# 31          Wrapped eETH   weeth          2216.150000             4253529148
# 32               Uniswap     uni             6.770000             4063212426
# 33                Monero     xmr           212.910000             3927592340
# 34         NEAR Protocol    near             2.790000             3317437688
# 35                   Dai     dai             0.999810             3286110773
# 36                 Aptos     apt             5.400000             3185116815
# 37                 sUSDS   susds             1.042000             3009445147
# 38                  Ondo    ondo             0.919723             2905271799
# 39                  Pepe    pepe             0.000007             2899863839
# 40     Internet Computer     icp             5.910000             2841215220
# 41      Ethereum Classic     etc            18.330000             2764807565
# 42                  Aave    aave           173.970000             2619711872
# 43                   OKB     okb            42.270000             2534019686
# 44                  Gate      gt            20.000000             2516408335
# 45        Official Trump   trump            12.240000             2448440003
# 46                Mantle     mnt             0.720479             2422897622
# 47  Coinbase Wrapped BTC   cbbtc         83735.000000             2404423478
# 48      Tokenize Xchange     tkx            29.050000             2321827843
# 49             Bittensor     tao           273.860000             2309587788
#
#     24h Trading Volume  24h Price Change (%)
# 0          74109155624              -8.75546
# 1          36705679454             -10.93826
# 2          70488305584              -0.01732
# 3          11204675331              -9.13576
# 4           1135631412              -5.77885
# 5           9909749792             -14.44701
# 6          16822964247              -0.00751
# 7           5731632961             -15.64084
# 8           2682953989             -12.17714
# 9           1288777912              -2.76720
# 10           152522709             -10.96900
# 11           816531915              -8.57547
# 12           587068182              -7.06659
# 13             8571424              -0.07322
# 14            63656775             -10.68473
# 15          1002232549             -14.98311
# 16           382923390             -12.87590
# 17           746374531             -14.73392
# 18            91872981               0.01332
# 19          1518709278             -11.99784
# 20          1331835130             -17.83040
# 21           293375216              -9.17894
# 22           453001061              -9.78516
# 23           170776664              -8.99546
# 24           370360401             -12.74066
# 25           596568693              -1.91349
# 26          1624000579             -10.97941
# 27           105311466              -0.16928
# 28           328016106             -18.22064
# 29           352856176             -10.31851
# 30           143788922              -3.17615
# 31            29342801             -10.88656
# 32           321287157             -13.70274
# 33            62917479              -9.02694
# 34           387348194             -14.67780
# 35           233806901               0.05166
# 36           360560274             -14.82292
# 37             1837046              -0.00602
# 38           363981662             -17.00783
# 39          1052470232             -16.21712
# 40           136324000             -12.70633
# 41           171526806              -7.63569
# 42           409512874             -15.24897
# 43            30599963              -8.58368
# 44            23504813              -8.54411
# 45          2200537086             -18.73334
# 46           118221506              -5.12180
# 47           514416953              -8.77281
# 48            14725315              -1.21082
# 49           118480692             -15.27207     Cryptocurrency Name Symbol  Current Price (USD)  Market Capitalization  \
# 0             Bitcoin    btc          83784.00000          1659945326387
# 1            Ethereum    eth           2090.18000           251736549098
# 2              Tether   usdt              0.99948           142421775931
# 3                 XRP    xrp              2.35000           135862241785
# 4                 BNB    bnb            565.05000            82404970312
#
#    24h Trading Volume  24h Price Change (%)
# 0         74109155624              -8.75546
# 1         36705679454             -10.93826
# 2         70488305584              -0.01732
# 3         11204675331              -9.13576
# 4          1135631412              -5.77885   5283.5413422714    Cryptocurrency Name Symbol  Current Price (USD)  Market Capitalization  \
# 35                 Dai    dai              0.99981             3286110773
#
#     24h Trading Volume  24h Price Change (%)
# 35           233806901               0.05166      Cryptocurrency Name Symbol  Current Price (USD)  Market Capitalization  \
# 45      Official Trump  trump                12.24             2448440003
#
#     24h Trading Volume  24h Price Change (%)
# 45          2200537086             -18.73334

# %%
# Function to update Excel sheet
def update_excel(df, top_5, avg_price, high_change, low_change):
    wb = Workbook()
    ws = wb.active
    ws.title = "Crypto Live Data"
    
    # Write main data
    for r in dataframe_to_rows(df, index=False, header=True):
        ws.append(r)
    
    # Write analysis section
    ws.append([])
    ws.append(["Top 5 Cryptocurrencies by Market Cap"])
    for r in dataframe_to_rows(top_5, index=False, header=True):
        ws.append(r)
    
    ws.append([])
    ws.append(["Average Price of Top 50 Cryptocurrencies", avg_price])
    
    ws.append([])
    ws.append(["Highest 24h Price Change"])
    for r in dataframe_to_rows(high_change, index=False, header=True):
        ws.append(r)
    
    ws.append([])
    ws.append(["Lowest 24h Price Change"])
    for r in dataframe_to_rows(low_change, index=False, header=True):
        ws.append(r)
    
    wb.save("crypto_live_data.xlsx")
    print("Excel updated successfully!")
update_excel(df, top_5, avg_price, high_change, low_change)
# Out:
# Excel updated successfully!

# %%
# Main function to run the live updating script
def main():
    while True:
        print("Fetching latest crypto data...")
        data = fetch_crypto_data()
        df, top_5, avg_price, high_change, low_change = analyze_data(data)
        update_excel(df, top_5, avg_price, high_change, low_change)
        print("Waiting for next update (5 minutes)...")
        time.sleep(300)  # Wait for 5 minutes before next update

# %%
# Run the script
if __name__ == "__main__":
    main()
# Out:
# Fetching latest crypto data...
# [{'id': 'bitcoin', 'symbol': 'btc', 'name': 'Bitcoin', 'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400', 'current_price': 83784, 'market_cap': 1659945326387, 'market_cap_rank': 1, 'fully_diluted_valuation': 1659945326387, 'total_volume': 74109155624, 'high_24h': 93668, 'low_24h': 82842, 'price_change_24h': -8039.554638590213, 'price_change_percentage_24h': -8.75546, 'market_cap_change_24h': -159339683743.8938, 'market_cap_change_percentage_24h': -8.75837, 'circulating_supply': 19832031.0, 'total_supply': 19832031.0, 'max_supply': 21000000.0, 'ath': 108786, 'ath_change_percentage': -22.87821, 'ath_date': '2025-01-20T09:11:54.494Z', 'atl': 67.81, 'atl_change_percentage': 123625.97228, 'atl_date': '2013-07-06T00:00:00.000Z', 'roi': None, 'last_updated': '2025-03-04T09:31:11.168Z'}, {'id': 'ethereum', 'symbol': 'eth', 'name': 'Ethereum', 'image': 'https://coin-images.coingecko.com/coins/images/279/large/ethereum.png?1696501628', 'current_price': 2090.18, 'market_cap': 251736549098, 'market_cap_rank': 2, 'fully_diluted_valuation': 251736549098, 'total_volume': 36705679454, 'high_24h': 2384.68, 'low_24h': 2035.18, 'price_change_24h': -256.70905570450486, 'price_change_percentage_24h': -10.93826, 'market_cap_change_24h': -30594264541.102295, 'market_cap_change_percentage_24h': -10.83632, 'circulating_supply': 120590104.1967597, 'total_supply': 120590104.1967597, 'max_supply': None, 'ath': 4878.26, 'ath_change_percentage': -57.02488, 'ath_date': '2021-11-10T14:24:19.604Z', 'atl': 0.432979, 'atl_change_percentage': 484089.57007, 'atl_date': '2015-10-20T00:00:00.000Z', 'roi': {'times': 32.35865906166368, 'currency': 'btc', 'percentage': 3235.8659061663675}, 'last_updated': '2025-03-04T09:31:14.656Z'}, {'id': 'tether', 'symbol': 'usdt', 'name': 'Tether', 'image': 'https://coin-images.coingecko.com/coins/images/325/large/Tether.png?1696501661', 'current_price': 0.99948, 'market_cap': 142421775931, 'market_cap_rank': 3, 'fully_diluted_valuation': 142421775931, 'total_volume': 70488305584, 'high_24h': 0.999828, 'low_24h': 0.998981, 'price_change_24h': -0.000173119803714927, 'price_change_percentage_24h': -0.01732, 'market_cap_change_24h': 33798234, 'market_cap_change_percentage_24h': 0.02374, 'circulating_supply': 142508685216.8603, 'total_supply': 142508685216.8603, 'max_supply': None, 'ath': 1.32, 'ath_change_percentage': -24.46637, 'ath_date': '2018-07-24T00:00:00.000Z', 'atl': 0.572521, 'atl_change_percentage': 74.55813, 'atl_date': '2015-03-02T00:00:00.000Z', 'roi': None, 'last_updated': '2025-03-04T09:31:12.214Z'}, {'id': 'ripple', 'symbol': 'xrp', 'name': 'XRP', 'image': 'https://coin-images.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442', 'current_price': 2.35, 'market_cap': 135862241785, 'market_cap_rank': 4, 'fully_diluted_valuation': 234416505266, 'total_volume': 11204675331, 'high_24h': 2.7, 'low_24h': 2.24, 'price_change_24h': -0.23603815347019141, 'price_change_percentage_24h': -9.13576, 'market_cap_change_24h': -13445677145.28418, 'market_cap_change_percentage_24h': -9.00533, 'circulating_supply': 57949738512.0, 'total_supply': 99986390660.0, 'max_supply': 100000000000.0, 'ath': 3.4, 'ath_change_percentage': -30.81168, 'ath_date': '2018-01-07T00:00:00.000Z', 'atl': 0.00268621, 'atl_change_percentage': 87433.48874, 'atl_date': '2014-05-22T00:00:00.000Z', 'roi': None, 'last_updated': '2025-03-04T09:31:10.948Z'}, {'id': 'binancecoin', 'symbol': 'bnb', 'name': 'BNB', 'image': 'https://coin-images.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970', 'current_price': 565.05, 'market_cap': 82404970312, 'market_cap_rank': 5, 'fully_diluted_valuation': 82404970312, 'total_volume': 1135631412, 'high_24h': 608.28, 'low_24h': 548.88, 'price_change_24h': -34.65607165580002, 'price_change_percentage_24h': -5.77885, 'market_cap_change_24h': -5103788622.633133, 'market_cap_change_percentage_24h': -5.83232, 'circulating_supply': 145887575.79, 'total_supply': 145887 ...
#      Cryptocurrency Name  Symbol  Current Price (USD)  Market Capitalization  \
# 0                Bitcoin     btc         83784.000000          1659945326387
# 1               Ethereum     eth          2090.180000           251736549098
# 2                 Tether    usdt             0.999480           142421775931
# 3                    XRP     xrp             2.350000           135862241785
# 4                    BNB     bnb           565.050000            82404970312
# 5                 Solana     sol           136.410000            69273901781
# 6                   USDC    usdc             0.999813            56262300308
# 7                Cardano     ada             0.807069            28965681534
# 8               Dogecoin    doge             0.191972            28382688767
# 9                   TRON     trx             0.233832            20101650006
# 10     Lido Staked Ether   steth          2088.380000            19590164114
# 11       Wrapped Bitcoin    wbtc         83637.000000            10797865655
# 12                Hedera    hbar             0.230575             9689742353
# 13             LEO Token     leo             9.940000             9195415523
# 14         Wrapped stETH  wsteth          2498.730000             8893446083
# 15             Chainlink    link            13.730000             8759345866
# 16               Stellar     xlm             0.284484             8717134728
# 17             Avalanche    avax            19.910000             8242980946
# 18                  USDS    usds             0.999517             7952214804
# 19              Litecoin     ltc           102.460000             7743614525
# 20                   Sui     sui             2.410000             7634420862
# 21               Toncoin     ton             3.040000             7537060576
# 22             Shiba Inu    shib             0.000013             7463048524
# 23                MANTRA      om             6.840000             6668341791
# 24              Polkadot     dot             4.240000             6473417238
# 25          Bitcoin Cash     bch           309.720000             6146412240
# 26                  WETH    weth          2088.960000             5990335932
# 27           Ethena USDe    usde             0.998340             5450223589
# 28           Hyperliquid    hype            15.830000             5323706148
# 29          Bitget Token     bgb             4.170000             4998935730
# 30         WhiteBIT Coin     wbt            29.640000             4271512931
# 31          Wrapped eETH   weeth          2216.150000             4253529148
# 32               Uniswap     uni             6.770000             4063212426
# 33                Monero     xmr           212.910000             3927592340
# 34         NEAR Protocol    near             2.790000             3317437688
# 35                   Dai     dai             0.999810             3286110773
# 36                 Aptos     apt             5.400000             3185116815
# 37                 sUSDS   susds             1.042000             3009445147
# 38                  Ondo    ondo             0.919723             2905271799
# 39                  Pepe    pepe             0.000007             2899863839
# 40     Internet Computer     icp             5.910000             2841215220
# 41      Ethereum Classic     etc            18.330000             2764807565
# 42                  Aave    aave           173.970000             2619711872
# 43                   OKB     okb            42.270000             2534019686
# 44                  Gate      gt            20.000000             2516408335
# 45        Official Trump   trump            12.240000             2448440003
# 46                Mantle     mnt             0.720479             2422897622
# 47  Coinbase Wrapped BTC   cbbtc         83735.000000             2404423478
# 48      Tokenize Xchange     tkx            29.050000             2321827843
# 49             Bittensor     tao           273.860000             2309587788
#
#     24h Trading Volume  24h Price Change (%)
# 0          74109155624              -8.75546
# 1          36705679454             -10.93826
# 2          70488305584              -0.01732
# 3          11204675331              -9.13576
# 4           1135631412              -5.77885
# 5           9909749792             -14.44701
# 6          16822964247              -0.00751
# 7           5731632961             -15.64084
# 8           2682953989             -12.17714
# 9           1288777912              -2.76720
# 10           152522709             -10.96900
# 11           816531915              -8.57547
# 12           587068182              -7.06659
# 13             8571424              -0.07322
# 14            63656775             -10.68473
# 15          1002232549             -14.98311
# 16           382923390             -12.87590
# 17           746374531             -14.73392
# 18            91872981               0.01332
# 19          1518709278             -11.99784
# 20          1331835130             -17.83040
# 21           293375216              -9.17894
# 22           453001061              -9.78516
# 23           170776664              -8.99546
# 24           370360401             -12.74066
# 25           596568693              -1.91349
# 26          1624000579             -10.97941
# 27           105311466              -0.16928
# 28           328016106             -18.22064
# 29           352856176             -10.31851
# 30           143788922              -3.17615
# 31            29342801             -10.88656
# 32           321287157             -13.70274
# 33            62917479              -9.02694
# 34           387348194             -14.67780
# 35           233806901               0.05166
# 36           360560274             -14.82292
# 37             1837046              -0.00602
# 38           363981662             -17.00783
# 39          1052470232             -16.21712
# 40           136324000             -12.70633
# 41           171526806              -7.63569
# 42           409512874             -15.24897
# 43            30599963              -8.58368
# 44            23504813              -8.54411
# 45          2200537086             -18.73334
# 46           118221506              -5.12180
# 47           514416953              -8.77281
# 48            14725315              -1.21082
# 49           118480692             -15.27207     Cryptocurrency Name Symbol  Current Price (USD)  Market Capitalization  \
# 0             Bitcoin    btc          83784.00000          1659945326387
# 1            Ethereum    eth           2090.18000           251736549098
# 2              Tether   usdt              0.99948           142421775931
# 3                 XRP    xrp              2.35000           135862241785
# 4                 BNB    bnb            565.05000            82404970312
#
#    24h Trading Volume  24h Price Change (%)
# 0         74109155624              -8.75546
# 1         36705679454             -10.93826
# 2         70488305584              -0.01732
# 3         11204675331              -9.13576
# 4          1135631412              -5.77885   5283.5413422714    Cryptocurrency Name Symbol  Current Price (USD)  Market Capitalization  \
# 35                 Dai    dai              0.99981             3286110773
#
#     24h Trading Volume  24h Price Change (%)
# 35           233806901               0.05166      Cryptocurrency Name Symbol  Current Price (USD)  Market Capitalization  \
# 45      Official Trump  trump                12.24             2448440003
#
#     24h Trading Volume  24h Price Change (%)
# 45          2200537086             -18.73334
# Excel updated successfully!
# Waiting for next update (5 minutes)...
